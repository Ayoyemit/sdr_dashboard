# %% [markdown]
# ## Loading the data

# %%
# %pip install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting streamlit
#   Downloading streamlit-1.45.1-py3-none-any.whl.metadata (8.9 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Using cached altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: blinker<2,>=1.5.0 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from streamlit) (1.9.0)
# Collecting cachetools<6,>=4.0 (from streamlit)
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: click<9,>=7.0 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.23 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from streamlit) (24.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from streamlit) (10.3.0)
# Collecting protobuf<7,>=3.20 (from streamlit)
#   Downloading protobuf-6.31.1-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-20.0.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Requirement already satisfied: requests<3,>=2.27 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from streamlit) (9.0.0)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from streamlit) (4.12.2)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Using cached GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from streamlit) (6.4)
# Requirement already satisfied: jinja2 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from altair<6,>=4.0->streamlit) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Collecting narwhals>=1.14.2 (from altair<6,>=4.0->streamlit)
#   Downloading narwhals-1.41.0-py3-none-any.whl.metadata (11 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Using cached smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.20.0)
# Requirement already satisfied: six>=1.5 in /Users/ayoyemi.o/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.16.0)
# Downloading streamlit-1.45.1-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 45.1 MB/s eta 0:00:00a 0:00:01
# Using cached altair-5.5.0-py3-none-any.whl (731 kB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading protobuf-6.31.1-cp39-abi3-macosx_10_9_universal2.whl (425 kB)
# Downloading pyarrow-20.0.0-cp310-cp310-macosx_12_0_arm64.whl (30.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 51.0 MB/s eta 0:00:00a 0:00:01
# Using cached pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading narwhals-1.41.0-py3-none-any.whl (357 kB)
# Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: toml, smmap, pyarrow, protobuf, narwhals, cachetools, pydeck, gitdb, gitpython, altair, streamlit
# Successfully installed altair-5.5.0 cachetools-5.5.2 gitdb-4.0.12 gitpython-3.1.44 narwhals-1.41.0 protobuf-6.31.1 pyarrow-20.0.0 pydeck-0.9.1 smmap-5.0.2 streamlit-1.45.1 toml-0.10.2
#
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
import os

# Add the project root to the Python path
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
import numpy as np
from project_parameters import get_parameters, get_slider_params, calculate_derived_parameters
from model_run import run_model_dash
from global_func import reset_flags, reset_E, reset_HSS, reset_S
import pandas as pd
import os

# %%
#initialize global parameters
total_runs = 1
seeds = np.random.default_rng(2025).integers(low=0, high=1e6, size=total_runs)
MODEL = {
    "int_period": 12 * 3, #three years of implementation
    "n_months": 12 * 6,   #additional three years of maintainance
}
slider_params = get_slider_params()
base_params = get_parameters()

# %%
def generate_baseline_df(total_runs, seeds, MODEL, ind_dir, fac_dir):
    # df_ind_list = []
    # df_fac_list = []
    n_months = MODEL["n_months"]
    int_period = MODEL["int_period"]
    b_flags = reset_flags()
    b_HSS = reset_HSS(slider_params)
    b_S = reset_S(slider_params)
    b_E = reset_E()

    for run in range(total_runs):
        os.makedirs(ind_dir, exist_ok=True)
        os.makedirs(fac_dir, exist_ok=True)

        base_seed = seeds[run]
        rng_param = np.random.default_rng(base_seed)
        b_param = get_parameters(rng = rng_param)
        b_param = calculate_derived_parameters(b_param)
        b_param.update({"E": b_E, "S": b_S, "HSS": b_HSS
        })
        _, b_outcomes, b_fac = run_model_dash(b_param, b_flags, n_months, int_period, base_seed=base_seed)
        b_fac["Run"] = run
        b_outcomes["Run"] = run
        b_outcomes["Scenario"] = "Baseline"
        b_fac["Scenario"] = "Baseline"
        #df_fac_list.append(pd.DataFrame(b_fac))
        #df_ind_list.append(pd.DataFrame(b_outcomes))
        # Write to CSV per run
        b_outcomes.to_csv(os.path.join(ind_dir, f"ind_base_run_{run}.csv"), index=False)
        b_fac.to_csv(os.path.join(fac_dir, f"fac_base_run_{run}.csv"), index=False)
    # df_ind = pd.concat(df_ind_list, ignore_index=True)
    # df_ind["Scenario"] = "Baseline"
    # df_fac = pd.concat(df_fac_list, ignore_index=True)
    # df_fac["Scenario"] = "Baseline"
    # return df_fac, df_ind

# %% [markdown]
# ## Running the baseline model

# %%
ind_dir = "/Users/ayoyemi.o/Desktop/sdr-results/individual_data/"
fac_dir = "/Users/ayoyemi.o/Desktop/sdr-results/facility_data/"
generate_baseline_df(total_runs, seeds, MODEL, ind_dir, fac_dir)

# %%
def HSS_scenario(scenario_name):
    i_flags = reset_flags()
    i_HSS = reset_HSS(slider_params)
    i_S = reset_S(slider_params)
    i_E = reset_E()
    #demand
    i_flags['flag_SDR'] = 1
    i_flags['flag_CHV'] = 1
    i_flags['flag_ANC'] = 1
    i_flags['flag_LB'] = 1
    i_HSS["P_ANC"] = scenario_dic[scenario_name][0]
    i_HSS["P_L45"] = scenario_dic[scenario_name][1]
    i_HSS['CHV_memory'] = memory_dic[scenario_name]
    i_HSS['tau_decay'] = 6
    #supply
    i_flags['flag_performance'] = 1
    i_HSS["knowledge"] = scenario_dic[scenario_name][3]
    i_flags['flag_capacity'] = 1
    i_HSS["capacity_added"] = scenario_dic[scenario_name][2]
    i_flags['flag_labor'] = 1
    i_HSS["labor_ratio"] = scenario_dic[scenario_name][3]
    i_flags['flag_equipment'] = 1
    i_HSS["sensor_ratio"] = scenario_dic[scenario_name][3]
    i_flags['flag_refer'] = 1
    i_HSS["P_refer"] = scenario_dic[scenario_name][3]
    i_flags['flag_transfer'] = 1
    i_HSS["P_transfer"] = scenario_dic[scenario_name][3]
    return i_E, i_S, i_HSS, i_flags

#HSS conservative match
scenario_dic = {
    'conservative match': np.array([0.7, 0.53, 0.25, 1]),
    'conservative dismatch': np.array([0.7, 0.53, 0.125, 0.5]),
    'moderate match': np.array([0.8, 0.68, 0.5, 1]),
    'moderate dismatch': np.array([0.8, 0.68, 0.25, 0.5]),
    'aggressive match': np.array([0.9, 0.9, 0.85, 1]),
    'aggressive dismatch': np.array([0.9, 0.9, 0.425, 0.5]),
}

memory_dic = {
    'conservative match': "Always Forget",
    'conservative dismatch': "Always Forget",
    'moderate match': "Always Forget",
    'moderate dismatch': "Always Forget",
    'aggressive match': "Always Forget",
    'aggressive dismatch': "Always Forget",
}

# %%
def generate_intervention_df(total_runs, seeds, MODEL, scenario_name, ind_dir, fac_dir):
    # df_ind = pd.DataFrame()
    # df_ind_list = []
    # df_fac = pd.DataFrame()
    # df_fac_list = []
    n_months = MODEL["n_months"]
    int_period = MODEL["int_period"]
    i_E, i_S, i_HSS, i_flags = HSS_scenario(scenario_name)

    for run in range(total_runs):
        base_seed = seeds[run]
        rng_param = np.random.default_rng(base_seed)
        i_param = get_parameters(rng = rng_param)
        i_param = calculate_derived_parameters(i_param)
        i_param.update({"E": i_E, "S": i_S, "HSS": i_HSS
    })
        _, i_outcomes, i_fac = run_model_dash(i_param, i_flags, n_months, int_period, base_seed=base_seed)
        i_fac["Run"] = run
        i_outcomes["Run"] = run
        i_outcomes["Scenario"] = scenario_name
        i_fac["Scenario"] = scenario_name

        # Write to CSV per run
        i_outcomes.to_csv(os.path.join(ind_dir, f"ind_{scenario_name}_run_{run}.csv"), index=False)
        i_fac.to_csv(os.path.join(fac_dir, f"fac_{scenario_name}_run_{run}.csv"), index=False)
        # df_ind_list.append(pd.DataFrame(i_outcomes))
        # df_fac_list.append(pd.DataFrame(i_fac))

    # df_ind = pd.concat(df_ind_list, ignore_index=True)
    # df_ind["Scenario"] = scenario_name
    # df_fac = pd.concat(df_fac_list, ignore_index=True)
    # df_fac["Scenario"] = scenario_name
    # return df_fac, df_ind

# %% [markdown]
# ## Running the model for different scenarios

# %%
generate_intervention_df(total_runs, seeds, MODEL, 'conservative match', ind_dir, fac_dir)

# %%
generate_intervention_df(total_runs, seeds, MODEL, 'conservative dismatch', ind_dir, fac_dir)
# Out:
# /Users/tingtingji/Library/Python/3.9/lib/python/site-packages/scipy/optimize/_minpack_py.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)

# %%
generate_intervention_df(total_runs, seeds, MODEL, 'moderate match', ind_dir, fac_dir)
# Out:
# /Users/tingtingji/Library/Python/3.9/lib/python/site-packages/scipy/optimize/_minpack_py.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)

# %%
generate_intervention_df(total_runs, seeds, MODEL, 'moderate dismatch', ind_dir, fac_dir)
# Out:
# /Users/tingtingji/Library/Python/3.9/lib/python/site-packages/scipy/optimize/_minpack_py.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)

# %%
generate_intervention_df(total_runs, seeds, MODEL, 'aggressive match', ind_dir, fac_dir)
# Out:
# /Users/tingtingji/Library/Python/3.9/lib/python/site-packages/scipy/optimize/_minpack_py.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)

# %%
generate_intervention_df(total_runs, seeds, MODEL, 'aggressive dismatch', ind_dir, fac_dir)
# Out:
# /Users/tingtingji/Library/Python/3.9/lib/python/site-packages/scipy/optimize/_minpack_py.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
